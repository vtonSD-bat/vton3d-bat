# %%
import torch
preds = torch.load("data/vggt_predictions_scene03.pt", map_location="cpu")

# %%
pose_enc = torch.load("data/vggt_predictions_scene03.pt", map_location="cpu")["pose_enc"]

# %%
pose_enc
# Out:
# tensor([[[ 7.1792e-06,  4.5522e-06, -5.2112e-06, -1.3803e-05,  6.0907e-05,
#           -8.3861e-05,  1.0000e+00,  6.1875e-01,  6.1674e-01],
#          [ 1.2181e-01, -6.9073e-03, -9.7307e-03,  7.9999e-03, -8.6577e-02,
#           -3.0323e-02,  9.9565e-01,  6.2132e-01,  6.1982e-01],
#          [ 3.4323e-01, -2.4695e-02,  3.1631e-02,  1.2177e-02, -2.5161e-01,
#           -7.7534e-02,  9.6423e-01,  6.3077e-01,  6.2822e-01],
#          [ 5.3516e-01, -7.2636e-02,  2.1267e-01,  1.3603e-02, -4.1167e-01,
#           -1.2649e-01,  9.0198e-01,  6.3300e-01,  6.3197e-01],
#          [ 6.1611e-01, -1.4843e-01,  3.8928e-01,  1.4988e-02, -5.5733e-01,
#           -1.8303e-01,  8.0939e-01,  6.3781e-01,  6.3603e-01],
#          [ 6.3615e-01, -2.2759e-01,  6.5227e-01,  9.7531e-03, -7.2054e-01,
#           -2.3158e-01,  6.5366e-01,  6.4235e-01,  6.4171e-01],
#          [ 5.6141e-01, -3.0573e-01,  9.2889e-01,  2.3700e-03, -8.3054e-01,
#           -2.6185e-01,  4.9178e-01,  6.4618e-01,  6.4686e-01],
# ...

# %%
print(type(preds))
# Out:
# <class 'dict'>

# %%
preds
# Out:
# {'pose_enc': tensor([[[ 7.1792e-06,  4.5522e-06, -5.2112e-06, -1.3803e-05,  6.0907e-05,
#            -8.3861e-05,  1.0000e+00,  6.1875e-01,  6.1674e-01],
#           [ 1.2181e-01, -6.9073e-03, -9.7307e-03,  7.9999e-03, -8.6577e-02,
#            -3.0323e-02,  9.9565e-01,  6.2132e-01,  6.1982e-01],
#           [ 3.4323e-01, -2.4695e-02,  3.1631e-02,  1.2177e-02, -2.5161e-01,
#            -7.7534e-02,  9.6423e-01,  6.3077e-01,  6.2822e-01],
#           [ 5.3516e-01, -7.2636e-02,  2.1267e-01,  1.3603e-02, -4.1167e-01,
#            -1.2649e-01,  9.0198e-01,  6.3300e-01,  6.3197e-01],
#           [ 6.1611e-01, -1.4843e-01,  3.8928e-01,  1.4988e-02, -5.5733e-01,
#            -1.8303e-01,  8.0939e-01,  6.3781e-01,  6.3603e-01],
#           [ 6.3615e-01, -2.2759e-01,  6.5227e-01,  9.7531e-03, -7.2054e-01,
#            -2.3158e-01,  6.5366e-01,  6.4235e-01,  6.4171e-01],
#           [ 5.6141e-01, -3.0573e-01,  9.2889e-01,  2.3700e-03, -8.3054e-01,
# ...
